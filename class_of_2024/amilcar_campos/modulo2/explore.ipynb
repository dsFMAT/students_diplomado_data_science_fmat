# %%
import pandas as pd
pd.set_option('display.max_columns', None)

# %%
df = pd.read_csv("listings.csv")
df.head()
# Out:
#        id                          listing_url       scrape_id last_scraped  \
# 0   42196   https://www.airbnb.com/rooms/42196  20240622024440   2024-06-22
# 1   46352   https://www.airbnb.com/rooms/46352  20240622024440   2024-06-22
# 2   85368   https://www.airbnb.com/rooms/85368  20240622024440   2024-06-22
# 3  145779  https://www.airbnb.com/rooms/145779  20240622024440   2024-06-22
# 4  204553  https://www.airbnb.com/rooms/204553  20240622024440   2024-06-22
#
#         source                                              name  \
# 0  city scrape               50 sm Studio in the historic centre
# 1  city scrape                        A room in Pasolini's house
# 2  city scrape                              Garden House Bologna
# 3  city scrape                                       SINGLE ROOM
# 4  city scrape  Private Room & Bath Ex-Convent in Centro Storico
#
#                                          description  \
# 0  The studio is a fully restored ancient basemen...
# ...

# %%
df.to_csv("listings2.csv", index=False)
