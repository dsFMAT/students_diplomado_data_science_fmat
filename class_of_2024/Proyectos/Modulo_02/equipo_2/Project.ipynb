# %%
import pandas as pd

dataset = pd.read_csv("./data/listings_barcelona.csv")
dataset.head(5)
# Out:
#       id                         listing_url       scrape_id last_scraped  \
# 0  18674  https://www.airbnb.com/rooms/18674  20240906140800   2024-09-06
# 1  23197  https://www.airbnb.com/rooms/23197  20240906140800   2024-09-06
# 2  32711  https://www.airbnb.com/rooms/32711  20240906140800   2024-09-06
# 3  34241  https://www.airbnb.com/rooms/34241  20240906140800   2024-09-06
# 4  34981  https://www.airbnb.com/rooms/34981  20240906140800   2024-09-06
#
#         source                                               name  \
# 0  city scrape    Huge flat for 8 people close to Sagrada Familia
# 1  city scrape  Forum CCIB DeLuxe, Spacious, Large Balcony, relax
# 2  city scrape                   Sagrada Familia area - Còrsega 1
# 3  city scrape   Stylish Top Floor Apartment - Ramblas Plaza Real
# 4  city scrape               VIDRE HOME PLAZA REAL on LAS RAMBLAS
#
#                                          description  \
# 0  110m2 apartment to rent in Barcelona. Located ...
# ...

# %%
df = dataset.copy()
df[df.duplicated('id')]
# Out:
# Empty DataFrame
# ...

# %%
df[df['id'].isna()]
# Out:
# Empty DataFrame
# ...

# %%
#santMarti = df[df['neighbourhood'=='Sant Martí']]
#df['neighbourhood']

df[df['neighbourhood'].isna()]
# Out:
#                         id                                       listing_url  \
# 3                    34241                https://www.airbnb.com/rooms/34241
# 8                    41952                https://www.airbnb.com/rooms/41952
# 13                  337755               https://www.airbnb.com/rooms/337755
# 14                  341563               https://www.airbnb.com/rooms/341563
# 19                   71520                https://www.airbnb.com/rooms/71520
# ...                    ...                                               ...
# 19476  1234617881904918666  https://www.airbnb.com/rooms/1234617881904918666
# 19477  1234621063113396232  https://www.airbnb.com/rooms/1234621063113396232
# 19478  1234633310288552263  https://www.airbnb.com/rooms/1234633310288552263
# 19479  1234636058660290258  https://www.airbnb.com/rooms/1234636058660290258
# 19480  1234659029532006287  https://www.airbnb.com/rooms/1234659029532006287
#
# ...
